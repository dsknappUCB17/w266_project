# %% [markdown]
# ## Prep

# %%
import sys
sys.version
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# ## Scrape one crossword

# %%
test_url = 'https://www.xwordinfo.com/Crossword?date=9/23/2021'
r = requests.get(test_url)
src = r.content

# %%
soup = BeautifulSoup(src, 'html.parser')

# %%
# clues
clues = []
answers = []
for div in soup.select('.numclue div'):
    div_text = div.get_text(strip=True)
#     print(div)
    if ':' in div_text:
        k,v = div_text.rsplit(':', 1)
        clues.append(k)
        answers.append(v)
# Out:
# <div>1</div>
# <div>Proto-smartphones, in brief : <a href="/Finder?word=PDAS">PDAS</a></div>
# <div>5</div>
# <div>It may be flipped in anger, with "the" : <a href="/Finder?word=BIRD">BIRD</a></div>
# <div>9</div>
# <div>Companion, in Arabic : <a href="/Finder?word=SAHIB">SAHIB</a></div>
# <div>14</div>
# <div>Performance traditionally accompanied by the ipu heke (double gourd drum) : <a class="unique" href="/Finder?word=HULADANCE">HULADANCE</a></div>
# <div>16</div>
# <div>Protein-building acid type : <a href="/Finder?word=AMINO">AMINO</a></div>
# <div>17</div>
# <div>Marley of "Marley &amp; Me," for one : <a class="unique" href="/Finder?word=YELLOWLAB">YELLOWLAB</a></div>
# <div>18</div>
# <div>Unbending : <a href="/Finder?word=RIGID">RIGID</a></div>
# <div>19</div>
# <div>Insomniacs have them : <a href="/Finder?word=SLEEPLESSNIGHTS">SLEEPLESSNIGHTS</a></div>
# <div>21</div>
# <div>A pelican gulper is a type of one : <a href="/Finder?word=EEL">EEL</a></div>
# <div>22</div>
# <div>Parts of essential oils : <a href="/Finder?word=ESTERS">ESTERS</a></div>
# <div>26</div>
# <div>It's a wrap : <a href="/Finder?word=OBI">OBI</a></div>
# <div>27</div>
# <div>Didn't win or lose : <a href="/Finder?word=DREW">DREW</a></div>
# <div>29</div>
# <div>Eye ailments : <a href="/Finder?word=STYES">STYES</a></div>
# <div>31</div>
# <div>Evian, par exemple : <a href="/Finder?word=EAU">EAU</a></div>
# <div>33</div>
# <div>Food item that may be candied : <a href="/Finder?word=YAM">YAM</a></div>
# <div>36</div>
# <div>Blue Angels, e.g. : <a class="unique" href="/Finder?word=AEROBATS">AEROBATS</a></div>
# <div>38</div>
# <div>Failing spectacularly : <a class="unique" href="/Finder?word=GOINGUPINFLAMES">GOINGUPINFLAMES</a></div>
# <div>42</div>
# <div>Colonies construct them : <a class="unique" href="/Finder?word=ANTNESTS">ANTNESTS</a></div>
# <div>45</div>
# <div>Anderson Cooper, to Gloria Vanderbilt : <a href="/Finder?word=SON">SON</a></div>
# <div>46</div>
# <div>Network operated by the U.S. Space Force : <a href="/Finder?word=GPS">GPS</a></div>
# <div>47</div>
# <div>Part of a bar line : <a href="/Finder?word=STOOL">STOOL</a></div>
# <div>49</div>
# <div>Get red in the face? : <a href="/Finder?word=CHAP">CHAP</a></div>
# <div>53</div>
# <div>What starts with janeiro, in Rio : <a href="/Finder?word=ANO">ANO</a></div>
# <div>55</div>
# <div>Like mortgagors : <a href="/Finder?word=INDEBT">INDEBT</a></div>
# <div>58</div>
# <div>Actress Hagen with three Tonys : <a href="/Finder?word=UTA">UTA</a></div>
# <div>59</div>
# <div>Members of a wartime skywatching corps : <a class="psonly" href="/Finder?word=GROUNDOBSERVERS">GROUNDOBSERVERS</a></div>
# <div>63</div>
# <div>Frothy order : <a href="/Finder?word=LATTE">LATTE</a></div>
# <div>64</div>
# <div>Symbols often accompanying the phrase "Legalize it" : <a class="unique" href="/Finder?word=POTLEAVES">POTLEAVES</a></div>
# <div>66</div>
# <div>Seriously fancy : <a href="/Finder?word=ADORE">ADORE</a></div>
# <div>67</div>
# <div>Redacts, as sensitive information (suggested by three of this puzzle's answers) : <a class="unique" href="/Finder?word=BLACKSOUT">BLACKSOUT</a></div>
# <div>68</div>
# <div>Feinted on the ice : <a href="/Finder?word=DEKED">DEKED</a></div>
# <div>69</div>
# <div>Adam and Eve's third child : <a href="/Finder?word=SETH">SETH</a></div>
# <div>70</div>
# <div>Standard Oil offshoot : <a href="/Finder?word=ESSO">ESSO</a></div>
# <div>1</div>
# <div>Gym : <a href="/Finder?word=PHYSED">PHYSED</a></div>
# <div>2</div>
# <div>Burr, famously : <a href="/Finder?word=DUELER">DUELER</a></div>
# <div>3</div>
# <div>Genetic variant : <a href="/Finder?word=ALLELE">ALLELE</a></div>
# <div>4</div>
# <div>Something that's no good unless it's closed : <a href="/Finder?word=SALE">SALE</a></div>
# <div>5</div>
# <div>Blubbers : <a href="/Finder?word=BAWLS">BAWLS</a></div>
# <div>6</div>
# <div>Some safe harbors : <a href="/Finder?word=INLETS">INLETS</a></div>
# <div>7</div>
# <div>Electronics company that founded NBC : <a href="/Finder?word=RCA">RCA</a></div>
# <div>8</div>
# <div>Type of socialite officially discontinued in the U.K. in 1958 : <a href="/Finder?word=DEB">DEB</a></div>
# <div>9</div>
# <div>It's a wrap : <a href="/Finder?word=SARI">SARI</a></div>
# <div>10</div>
# <div>Mexican ally : <a href="/Finder?word=AMIGO">AMIGO</a></div>
# <div>11</div>
# <div>Flashy car feature? : <a href="/Finder?word=HIGHBEAM">HIGHBEAM</a></div>
# <div>12</div>
# <div>New member : <a href="/Finder?word=INITIATE">INITIATE</a></div>
# <div>13</div>
# <div>Gym figures, for short : <a href="/Finder?word=BODS">BODS</a></div>
# <div>15</div>
# <div>Lowdown : <a href="/Finder?word=DOPE">DOPE</a></div>
# <div>23</div>
# <div>Flight tracker info : <a href="/Finder?word=ETA">ETA</a></div>
# <div>24</div>
# <div>Alternative to white : <a href="/Finder?word=RYE">RYE</a></div>
# <div>25</div>
# <div>Peons : <a href="/Finder?word=SERFS">SERFS</a></div>
# <div>28</div>
# <div>Casino next to the Venetian in Vegas : <a href="/Finder?word=WYNN">WYNN</a></div>
# <div>30</div>
# <div>2018 sci-fi prequel : <a href="/Finder?word=SOLO">SOLO</a></div>
# <div>32</div>
# <div>___ Enterprise : <a href="/Finder?word=USS">USS</a></div>
# <div>34</div>
# <div>Range on a game box : <a href="/Finder?word=AGES">AGES</a></div>
# <div>35</div>
# <div>"Are you giving me no choice?" : <a href="/Finder?word=MUSTI">MUSTI</a></div>
# <div>37</div>
# <div>Like Supreme Court hearings, with "en" : <a href="/Finder?word=BANC">BANC</a></div>
# <div>38</div>
# <div>Shut up : <a href="/Finder?word=GAG">GAG</a></div>
# <div>39</div>
# <div>For all to see : <a href="/Finder?word=ONPARADE">ONPARADE</a></div>
# <div>40</div>
# <div>Response to rule-breaking : <a class="unique" href="/Finder?word=ITSNOTOK">ITSNOTOK</a></div>
# <div>43</div>
# <div>Whole lot : <a href="/Finder?word=TON">TON</a></div>
# <div>44</div>
# <div>Cover some ground? : <a href="/Finder?word=SOD">SOD</a></div>
# <div>48</div>
# <div>Titular vampire in Anne Rice novels : <a href="/Finder?word=LESTAT">LESTAT</a></div>
# <div>50</div>
# <div>Parts of a Spanish omelet : <a href="/Finder?word=HUEVOS">HUEVOS</a></div>
# <div>51</div>
# <div>Father-in-law of Helen of Troy : <a href="/Finder?word=ATREUS">ATREUS</a></div>
# <div>52</div>
# <div>Target with a toss : <a href="/Finder?word=PASSTO">PASSTO</a></div>
# <div>54</div>
# <div>Off-the-wall : <a href="/Finder?word=OUTRE">OUTRE</a></div>
# <div>56</div>
# <div>Something that might come up after a big meal? : <a href="/Finder?word=BELCH">BELCH</a></div>
# <div>57</div>
# <div>Enterprise voyage : <a href="/Finder?word=TREK">TREK</a></div>
# <div>59</div>
# <div>Hefty rival : <a href="/Finder?word=GLAD">GLAD</a></div>
# <div>60</div>
# <div>Have to have : <a href="/Finder?word=NEED">NEED</a></div>
# <div>62</div>
# <div>Container whose name is pronounced with either a long "a" or an "ah" : <a href="/Finder?word=VASE">VASE</a></div>
# <div>64</div>
# <div>Network supported by "Viewers Like You" : <a href="/Finder?word=PBS">PBS</a></div>
# <div>65</div>
# <div>___ Miss of the N.C.A.A. : <a href="/Finder?word=OLE">OLE</a></div>

# %%
crossword_df = pd.DataFrame(
    {'CLUE': clues,
     'ANSWER': answers
    })

crossword_df.head()
# Out:
#                                                 CLUE     ANSWER
# 0                       Proto-smartphones, in brief        PDAS
# 1            It may be flipped in anger, with "the"        BIRD
# 2                              Companion, in Arabic       SAHIB
# 3  Performance traditionally accompanied by the i...  HULADANCE
# 4                        Protein-building acid type       AMINO

# %% [markdown]
# ## Loop through multiple dates

# %%
cword_dates = pd.date_range("1/1/2015", periods=3, freq="D")
cword_dates = cword_dates.strftime('%m/%d/%Y')

# %%
cword_dates[1]
# Out:
# '01/02/2015'

# %%
base_url = 'https://www.xwordinfo.com/Crossword?date='

clues = []
answers = []
for date in cword_dates:
    cw_url = base_url + date
    r = requests.get(cw_url)
    src = r.content
    soup = BeautifulSoup(src, 'html.parser')
    for div in soup.select('.numclue div'):
        div_text = div.get_text(strip=True)
        if ':' in div_text:
#             print(div_text)
            k,v = div_text.rsplit(':', 1)
            clues.append(k)
            answers.append(v)

crossword_df = pd.DataFrame(
    {'CLUE': clues,
     'ANSWER': answers
    })

crossword_df.head()
# Out:
# Person close to 100? :ASTUDENT
# Kind of game or line :PICKUP
# Belt and hose :CARPARTS
# Poker declaration :IRAISE
# Neil Armstrong declaration :THEEAGLEHASLANDED
# Film critic Jeffrey :LYONS
# Part of a dovetail joint :TENON
# Sub :HERO
# Seizure sensors, for short :EEGS
# What a parent might warn a child to watch out for :THEBOGEYMAN
# Deviate from one's path :YAW
# Bash with a splash :POOLPARTY
# "___ inglés?" :HABLA
# Noir alternative :AULAIT
# Part of a Spanish explorer's name :DELEON
# "Funny Girl" composer :STYNE
# Chutes and ladders locale :WATERPARK
# Ho Chi Minh City festival :TET
# 1961 Tony winner for Best Musical :BYEBYEBIRDIE
# Sistine Chapel painting setting :EDEN
# Antennae, so to speak :EARS
# Charged :RANAT
# Butterfly, but not a caterpillar :IMAGO
# Average ... or a literal hint to 17-, 26- and 42-Across :PARFORTHECOURSE
# Cave :GROTTO
# Trump :OVERRULE
# Duke's transportation? :ATRAIN
# Game for which it's helpful to have hands-on experience? :PEEKABOO
# House work? :ACT
# Comedian Mort :SAHL
# Deuce follower :TREY
# Until :UPTO
# Beginning :DAWN
# "Now ___ shakes my soul": Sappho :EROS
# Highest power? :NTH
# Traveler's checks, for short? :TSA
# Not let up in criticism :PILEON
# Site of a 1953 C.I.A.-directed coup :IRAN
# Paddle around :CANOE
# Organlike legume :KIDNEYBEAN
# Function :USE
# Taxi eschewer, for short :PED
# Animal shelter animal :STRAY
# 2013 Joaquin Phoenix film :HER
# Chest compressor, for short :EMT
# In abundance :GALORE
# Ritzy :SWANK
# Promoted :TOUTED
# Real imp :HOLYTERROR
# Brio :ELAN
# Big name in morning radio :OPIE
# "The Confessions of ___ Turner" (1967 Pulitzer winner) :NAT
# Wallop :PASTE
# "___, boy!" :HERE
# Canned food made by Nestlé :ALPO
# "L.A. Law" actress :DEY
# Peter Fonda's role in "Easy Rider" :WYATT
# ___ Lingus :AER
# TV channel with the slogan "Very Funny" :TBS
# Concern :BEARON
# Clinton-backed pact :NAFTA
# "Don't blame me!" :NOTI
# Brain-freezing treat :ICEE
# Sitcom character who curses by shouting "Shazbot!" :MORK
# Special quality :AURA
# Eats :GRUB
# "Hedda Gabler" setting :OSLO
# Org. that's most likely to appreciate this puzzle? :PGA
# Sketches, e.g. :ART
# Short flight :HOP
# New Year's ___ :EVE
# Job ad abbr. :EEO
# One at the head of the class, informally :TEACH
# "Fearless" star, 2006 :JETLI
# Green yardstick :PAR
# They may be marked with X's :ADULTMOVIES
# Panegyrical lines :ODE
# What to call a cardinal :HISEMINENCE
# Shooter for kids :TAW
# 1958 #1 hit composed by Vice President Charles Dawes :ITSALLINTHEGAME
# Rouge counterpart :NOIR
# Slightly :ATAD
# Burning sensation? :IRE
# Stuffed accessories :PINCUSHIONS
# Pluto, for one :MINORPLANET
# Rats :TATTLETALES
# Brand maker? :REDHOTPOKER
# Classic computer game played on a grid :MINESWEEPER
# Sci-fi narcotic :TEK
# Leaning column? :OPED
# 10 micronewtons :DYNE
# Group for people who are feeling blue? :DEMOCRATICPARTY
# Sierra Leone-to-Burkina Faso dir. :ENE
# Hocus-pocus :LEGERDEMAIN
# Sportswriter Pasquarelli :LEN
# Living :INEXISTENCE
# "The proper task of life," per Nietzsche :ART
# Modern connection points :PORTS
# Newbery Medal-winning author Eleanor :ESTES
# Falafel topper :TAHINI
# One with paper cuts? :EDITOR
# Kiwi's neighbor :AUSSIE
# Calculator button :CLEAR
# Code with tags :HTML
# Mitchell with the platinum album "Blue" :JONI
# Like 2014 but not 2015 :EVEN
# Salon job :TINT
# Source of dirty looks :LECH
# Roman "video" :ISEE
# Fries things? :POTATOES
# Disinclined to move :ADAMANT
# Takes a second? :REWEDS
# 1,000 G's :MIL
# It's a dive :GAINER
# Hearts :PITHS
# Tagging along :INTOW
# People's 1992 Sexiest Man Alive :NOLTE
# Brunch offering :CREPE
# High-five request :UPTOP
# Satisfy :SLAKE
# Comparatively sound :HALER
# Got by :MADEDO
# Place where people lived in "How the Other Half Lives" :TENEMENT
# It might change color :RIPENER
# Detroit debut of 1927 :MODELA
# Fist-pounding boss, say :TYRANT
# Be coquettish with :ENTICE
# Macroeconomics pioneer :KEYNES
# Women, in pulp fiction :DAMES
# YouTube upload :CLIP
# Member of Clinton's cabinet for all eight years :RENO
# New ___ :AGER
# Part of 5-Down :TEXT
# Long-stemmed flower :IRIS
# There's not much interest in these nowadays :CDS
# Best of classic rock :PETE
# Bollix :BOTCH
# Rough selection? :SEVENIRON
# 1975 Golden Globe winner :RHODA
# Merry Men member :ALANADALE
# Marty Robbins's "___ the Lucky One" :AINTI
# One doing 40+? :FULLTIMER
# Speech closing? :IFY
# They're laid down in shipyards :KEELS
# Notice after the expiration date? :OBIT
# "Uh, yeah!" :NODOUBT
# ___ Rebellion (colonial uprising) :BACONS
# Just for Men target :GRAY
# Incidentally :BYTHEBY
# Auntie Mame's secretary :AGNES
# Rear of a disco? :BOOTY
# "___ Jeunes de Paris" (recurring "S.N.L." sketch) :LES
# Munchie often dipped in marinara :MOZZARELLASTICK
# Info for air traffic control :ETA
# Like some carpets and autumn leaves :PILED
# Classic Harlem ballroom, with "the" :SAVOY
# Feature of many a convertible or Jeep :SOFTTOP
# Hinge :RELY
# "The Return of Doctor X" star, 1939 :BOGART
# Poet Howard who wrote "A Primer of the Daily Round" :NEMEROV
# Aéroports de Paris manages it :ORLY
# Kofi Annan's home :GHANA
# Before now :AGO
# Ball carriers :TOYSTORES
# Completely fixed :REDID
# Its last model was the 1941 Skylark :HUPMOBILE
# Dean's "East of Eden" role :TRASK
# Eschewing a higher calling? :ATHEISTIC
# Maker of iComfort :SERTA
# Crossword, e.g. :BRAINGAME
# "Oops, that had escaped me" :OHIFORGOT
# Boxer-turned-sitcom star :TONYDANZA
# Setting for Twins games: Abbr. :CDT
# Traditional three-liner :HAIKU
# Ejection protection :SAFETYBELT
# Month in which Creation began, by tradition :ELUL
# Triple-time dance, in Durango :VALS
# Size up?: Abbr. :ENL
# Phillie foe :NAT
# Senselessness :IDIOCY
# No wuss :RAMBO
# Liquid part of fat :OLEIN
# "Shoot!" :NERTS
# Leave shore, perhaps :EBB
# Cry for attention :OYEZ
# Test letter? :BETA
# It's unfathomable :ABYSS
# Flat sign :TOLET
# "Whoa, whoa!" :HOLDONASEC
# Taste :SAPOR
# Real-time storm tracker :LIVERADAR
# One concerned with invasive species :ECOLOGIST
# Liquor with the slogan "West of Expected" :SKYYVODKA
# Major fault :RIFT
# Something discounted at a deli? :TARE
# Argument-ending declaration :SAYSME
# One with a signature role? :PEN
# De Klerk succeeded him :BOTHA
# "In ___?" :OROUT
# Rosetta Stone figure :GLYPH
# Trading places :MARTS
# Clench :GRIT
# Start to ski? :HELI
# "Vous," informally :TOI
# Special delivery figs.? :OBS
# Ahead of, once :ERE
#                           CLUE             ANSWER
# 0        Person close to 100?            ASTUDENT
# 1        Kind of game or line              PICKUP
# 2               Belt and hose            CARPARTS
# 3           Poker declaration              IRAISE
# 4  Neil Armstrong declaration   THEEAGLEHASLANDED
